# %% [markdown]
# # Stage 1 Data Cleaning
#
# This notebook is a lightweight companion to the main cleaning script. The production-ready cleaning workflow lives in `scripts/01_data_cleaning.py`.

# %%
from pathlib import Path
import subprocess
import sys

project_root = Path.cwd()
if project_root.name == "notebooks":
    project_root = project_root.parent

script_path = project_root / "scripts" / "01_data_cleaning.py"
subprocess.run([sys.executable, str(script_path)], cwd=project_root, check=True)

# %%
import pandas as pd

processed_dir = project_root / "data" / "processed"
summary = pd.read_csv(processed_dir / "data_cleaning_summary.csv")
summary

# %%
clean_transactions = pd.read_csv(processed_dir / "clean_retail_transactions.csv", nrows=5)
clean_transactions

# %%
sales_transactions = pd.read_csv(processed_dir / "sales_transactions_only.csv", nrows=5)
sales_transactions
